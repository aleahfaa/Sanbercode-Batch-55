# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
warna=['red', 'green', 'blue', 'yellow']
plt.figure(figsize=(10, 6))
plt.plot(x, cos, label='Cos(x)', color=warna[0])
plt.plot(x, cos3, label='3Cos(x)', color=warna[1], linestyle='dashed')
plt.plot(x, sin, label='Sin(x-90)', color=warna[2], linestyle='dashdot')
plt.plot(x, sin2, label='2Sin(x)', color=warna[3], marker='x')
plt.xlabel('X-Axis Label')
plt.ylabel('YAxis Label')
plt.title('Grafik Cos Sin')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
